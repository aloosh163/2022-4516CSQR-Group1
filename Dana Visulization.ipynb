# %%
import pandas as pd
Start=pd.read_csv('Final.csv')
Start
# Out:
#       Unnamed: 0  Incedents         Date     Time   \
# 0              0          1  17/Sep/1908   5:18 PM
# 1              1          2  09/Jul/1909  10:00 AM
# 2              2          3  07/Dec/1912   6:30 AM
# 3              3          4  08/Jun/1913       NaN
# 4              4          5  09/Sep/1913   6:30 PM
# ...          ...        ...          ...       ...
# 5009        5009       5010  06/Oct/2021   8:00 AM
# 5010        5010       5011  07/Apr/2021    11:30
# 5011        5011       5012  07/Jun/2021   3:00 PM
# 5012        5012       5013  09/Dec/2021  11:15 PM
# 5013        5013       5014  27/Dec/2021   7:14 PM
#
#                                   Location                           Operator  \
# 0                     Fort Myer, Virginia               Military - U.S. Army
# 1                 Juvisy-sur-Orge, France                   \tEugene Lefebvre
# 2               Atlantic City, New Jersey               Military - U.S. Navy
# ...

# %%
Start['Toatal death']=Start['Death'].str.replace(r"\(.*\)","")
# Out:
# C:\Users\dkalb\AppData\Local\Temp/ipykernel_17496/465392223.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Start['Toatal death']=Start['Death'].str.replace(r"\(.*\)","")

# %%
Start['Toatal death']=Start['Toatal death'].astype(float)
Start.head(5)
# Out:
#    Unnamed: 0  Incedents         Date     Time   \
# 0           0          1  17/Sep/1908   5:18 PM
# 1           1          2  09/Jul/1909  10:00 AM
# 2           2          3  07/Dec/1912   6:30 AM
# 3           3          4  08/Jun/1913       NaN
# 4           4          5  09/Sep/1913   6:30 PM
#
#                                Location                  Operator  \
# 0                  Fort Myer, Virginia      Military - U.S. Army
# 1              Juvisy-sur-Orge, France          \tEugene Lefebvre
# 2            Atlantic City, New Jersey      Military - U.S. Navy
# 3   Victoria, British Columbia, Canada                   Private
# 4                   Over the North Sea    Military - German Navy
#
#                  Route                   AC Type Registration cn / In  \
# 0       Demonstration          Wright Flyer III          SC-1       1
# 1            Air show            Wright Byplane          SC1      NaN
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
number1=Start.groupby('Operator')[['Operator']].count()
plt.figure(figsize=(13,7))
Graph = number1.rename(columns={"Operator": "Total_Operator"})
Graph1 = Graph.sort_values(by='Total_Operator', ascending=False).head(15)
sns.barplot(y=Graph1.index, x="Total_Operator", data=Graph1, color='pink')
plt.xlabel('Total', fontsize=15)
plt.ylabel('Operator_type', fontsize=15)
plt.title('Total of operators', loc='right', fontsize=15)
plt.show()

# %%
number2=Start.groupby('Operator')[['Toatal death']].sum()
Graph1 = number2.sort_values(by='Toatal death', ascending=False).head(15)
plt.figure(figsize=(13,7))
sns.barplot(y=Graph1.index, x="Toatal death", data=Graph1, color='pink')
plt.xlabel('Total_Deaths', fontsize=15)
plt.ylabel('Operator_Type', fontsize=15)
plt.title('Total_Deaths by Operator ', loc='right', fontsize=15)
plt.show()
