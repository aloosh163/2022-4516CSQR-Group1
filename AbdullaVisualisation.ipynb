# %%
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
df=pd.read_csv('Final.csv')
df
# Out:
#       Unnamed: 0  Incedents         Date     Time   \
# 0              0          1  17/Sep/1908   5:18 PM
# 1              1          2  09/Jul/1909  10:00 AM
# 2              2          3  07/Dec/1912   6:30 AM
# 3              3          4  08/Jun/1913       NaN
# 4              4          5  09/Sep/1913   6:30 PM
# ...          ...        ...          ...       ...
# 5009        5009       5010  06/Oct/2021   8:00 AM
# 5010        5010       5011  07/Apr/2021    11:30
# 5011        5011       5012  07/Jun/2021   3:00 PM
# 5012        5012       5013  09/Dec/2021  11:15 PM
# 5013        5013       5014  27/Dec/2021   7:14 PM
#
#                                   Location                           Operator  \
# 0                     Fort Myer, Virginia               Military - U.S. Army
# 1                 Juvisy-sur-Orge, France                   \tEugene Lefebvre
# 2               Atlantic City, New Jersey               Military - U.S. Navy
# ...

# %%
df['Death']=df['Death'].str.replace(r"\(.*\)","")
# Out:
# C:\Users\ok817\AppData\Local\Temp/ipykernel_30964/4179034621.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Death']=df['Death'].str.replace(r"\(.*\)","")

# %%
df['Aboard']=df['Aboard'].str.replace(r"\(.*\)","")
# Out:
# C:\Users\ok817\AppData\Local\Temp/ipykernel_30964/2096051925.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Aboard']=df['Aboard'].str.replace(r"\(.*\)","")

# %%
df.head(4)
# Out:
#    Unnamed: 0  Incedents         Date     Time   \
# 0           0          1  17/Sep/1908   5:18 PM
# 1           1          2  09/Jul/1909  10:00 AM
# 2           2          3  07/Dec/1912   6:30 AM
# 3           3          4  08/Jun/1913       NaN
#
#                                Location                Operator  \
# 0                  Fort Myer, Virginia    Military - U.S. Army
# 1              Juvisy-sur-Orge, France        \tEugene Lefebvre
# 2            Atlantic City, New Jersey    Military - U.S. Navy
# 3   Victoria, British Columbia, Canada                 Private
#
#              Route             AC Type Registration cn / In Aboard Death  \
# 0   Demonstration    Wright Flyer III          SC-1       1    2     1
# 1        Air show      Wright Byplane          SC1      NaN    1     1
# 2     Test flight           Dirigible           NaN     NaN    5     5
# 3         Victoria   Curtiss seaplane           NaN     NaN    1     1
#
# ...

# %%
df['Death']=df['Death'].astype(float)
df['Aboard']=df['Aboard'].astype(float)
df.head(5)
# Out:
#    Unnamed: 0  Incedents         Date     Time   \
# 0           0          1  17/Sep/1908   5:18 PM
# 1           1          2  09/Jul/1909  10:00 AM
# 2           2          3  07/Dec/1912   6:30 AM
# 3           3          4  08/Jun/1913       NaN
# 4           4          5  09/Sep/1913   6:30 PM
#
#                                Location                  Operator  \
# 0                  Fort Myer, Virginia      Military - U.S. Army
# 1              Juvisy-sur-Orge, France          \tEugene Lefebvre
# 2            Atlantic City, New Jersey      Military - U.S. Navy
# 3   Victoria, British Columbia, Canada                   Private
# 4                   Over the North Sea    Military - German Navy
#
#                  Route                   AC Type Registration cn / In  Aboard  \
# 0       Demonstration          Wright Flyer III          SC-1       1     2.0
# 1            Air show            Wright Byplane          SC1      NaN     1.0
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Incedents         int64
# Date             object
# Time             object
# Location         object
# Operator         object
# Route            object
# AC Type          object
# Registration     object
# cn / In          object
# Aboard          float64
# Death           float64
# Ground           object
# Summary          object
# dtype: object

# %%
df['Survive']=df['Aboard']-df['Death']
df.head(3)
# Out:
#    Unnamed: 0  Incedents         Date     Time                      Location  \
# 0           0          1  17/Sep/1908   5:18 PM         Fort Myer, Virginia
# 1           1          2  09/Jul/1909  10:00 AM     Juvisy-sur-Orge, France
# 2           2          3  07/Dec/1912   6:30 AM   Atlantic City, New Jersey
#
#                  Operator            Route             AC Type Registration  \
# 0   Military - U.S. Army    Demonstration    Wright Flyer III          SC-1
# 1       \tEugene Lefebvre        Air show      Wright Byplane          SC1
# 2   Military - U.S. Navy      Test flight           Dirigible           NaN
#
#   cn / In  Aboard  Death Ground  \
# 0       1     2.0    1.0      0
# 1     NaN     1.0    1.0      0
# 2     NaN     5.0    5.0      0
#
#                                              Summary  Survive
# 0   During a demonstration flight, a U.S. Army fl...      1.0
# 1   Eugene Lefebvre was the first pilot to ever b...      0.0
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Year']=df['Date'].dt.year

# %%
df.head(5)
# Out:
#    Unnamed: 0  Incedents       Date     Time   \
# 0           0          1 1908-09-17   5:18 PM
# 1           1          2 1909-07-09  10:00 AM
# 2           2          3 1912-12-07   6:30 AM
# 3           3          4 1913-06-08       NaN
# 4           4          5 1913-09-09   6:30 PM
#
#                                Location                  Operator  \
# 0                  Fort Myer, Virginia      Military - U.S. Army
# 1              Juvisy-sur-Orge, France          \tEugene Lefebvre
# 2            Atlantic City, New Jersey      Military - U.S. Navy
# 3   Victoria, British Columbia, Canada                   Private
# 4                   Over the North Sea    Military - German Navy
#
#                  Route                   AC Type Registration cn / In  Aboard  \
# 0       Demonstration          Wright Flyer III          SC-1       1     2.0
# 1            Air show            Wright Byplane          SC1      NaN     1.0
# ...

# %%
todo=df.groupby(['Year'])[['Death']].sum()
todo
# Out:
#       Death
# Year
# 1908    1.0
# 1909    1.0
# 1912    5.0
# 1913   43.0
# 1915   36.0
# ...     ...
# 2017  214.0
# 2018  874.0
# 2019  305.0
# 2020  355.0
# 2021  186.0
#
# [111 rows x 1 columns]

# %%
got=df.loc[:,['Year','Death','Survive']].groupby(['Year']).sum()
plot=got.plot.bar(stacked=True,figsize=(20,12))
plt.style.use('seaborn-white')
plt.title('Yearly Survived and Death',fontsize=20)
plt.xlabel('Year')
plt.ylabel("Number of people Aboard")
plt.show()

# %%
routes=df['Route']
routes=routes.dropna().str.lower().str.replace(" ", "").str.split("-")
routes=routes[routes.str.len()==2]
dept2Dest=pd.DataFrame({'Departure': routes.str.get(0), 'Destination': routes.str.get(1)})

# %%
departure = dept2Dest.groupby(['Destination']).count().sort_values(by="Departure", ascending=False).head(10)
Dep = departure.plot.bar(figsize=(10,5), title="Top Ten Most Dangerous City for Departure", fontsize=13)
plt.style.use('ggplot')
Dep.set_xlabel("City", fontsize=15)
Dep.set_ylabel("Number of Crash", fontsize=10)
# Out:
# Text(0, 0.5, 'Number of Crash')

# %%
destination = dept2Dest.groupby(['Departure']).count().sort_values(by="Destination", ascending=False).head(10)
plot8 = destination.plot.bar(figsize=(10,5), title="Top Ten Most Dangerous City for Destination", fontsize=13,color='Blue')
plt.style.use('ggplot')
plot8.set_xlabel("City", fontsize=15)
plot8.set_ylabel("Number of Crash", fontsize=10)
# Out:
# Text(0, 0.5, 'Number of Crash')
